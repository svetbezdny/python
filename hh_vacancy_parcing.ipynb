# %% [markdown]
# ### Parcing vacancies from [hh.ru](https://hh.ru/?hhtmFrom=vacancy) by keywords
# ___

# %%
import pandas as pd
import requests
import re
from time import sleep


pd.set_option('display.max_rows', 50)
pd.set_option('display.max_columns', 50)

# %%
# city number
area = 1

# interesting competencies to search for
search_keywords = ['sql',
                   'postgresql',
                   'pandas',
                   'power bi',
                   'power query',
                   'power pivot'
                   'dax']

search_keywords = '+or+'.join([i.replace(' ', '+') for i in search_keywords])

# %%
n = 10    # number of pages
columns = ['name', 'salary', 'address', 'published_at', 'alternate_url', 'employer', 'snippet', 'schedule']    # keys from json

lst = []
for page in range(n):
    url = f'http://api.hh.ru/vacancies?text={search_keywords}&area={area}&per_page=100&page={page}'
    data = requests.get(url).json()
    
    sleep(2)

    for i in data['items']:
        lst.append(i)

# %%
df = pd.DataFrame(lst, columns=columns)

# %%
df['employer'] = df['employer'].map(lambda x: x['name'])
df['schedule'] = df['schedule'].map(lambda x: x['name'])

address = pd.json_normalize(df['address'])[['metro.station_name', 'metro.line_name']]
salary = pd.json_normalize(df['salary']).iloc[:, [0, 1, 3]].rename(columns={'from':'salary_from', 'to':'salary_to'})
salary['gross'] = salary['gross'] * 1
snippet = pd.json_normalize(df['snippet'])

# %%
df = pd.concat([df.drop(columns=(['address', 'snippet', 'salary'])), address, snippet, salary], axis=1)

# %%
df['requirement'] = df['requirement'].map(lambda x: re.sub('<[^>]*>', '', x) if x != None else None)
df['responsibility'] = df['responsibility'].map(lambda x: re.sub('<[^>]*>', '', x) if x != None else None)

# %%
df['published_at'] = pd.to_datetime(df['published_at']).dt.tz_localize(None)
df.sort_values(by='published_at', ascending=False, inplace=True)

# %%
df = df[['published_at', 'employer', 'name', 'requirement', 
         'responsibility', 'salary_from', 'salary_to', 'gross', 
         'schedule', 'metro.station_name', 'metro.line_name', 'alternate_url']]

# %%
# adding columns for filtering

df['has_sql'] = df['requirement'].map(lambda x: 'sql' in x.lower() if x != None else None) * 1
df['has_postgresql'] = df['requirement'].map(lambda x: 'postgresql' in x.lower() if x != None else None) * 1
df['has_pandas'] = df['requirement'].map(lambda x: 'pandas' in x.lower() if x != None else None) * 1
df['has_powerbi'] = df['requirement'].map(lambda x: 'power bi' in x.lower() if x != None else None) * 1
df['has_excel'] = df['requirement'].map(lambda x: any([i in x.lower() for i in ['power query, power pivot', 'dax']]) if x != None else None) * 1

# %%
df.head(10)
# Out:
#            published_at                                           employer  \
# 384 2023-03-03 22:24:17                   ТрансМашХолдинг, Группа компаний
# 705 2023-03-03 22:20:47                                           Тинькофф
# 938 2023-03-03 22:20:47                                           Тинькофф
# 571 2023-03-03 22:17:00                                       Paper Planes
# 352 2023-03-03 22:08:31                         Ельмикеев Евгений Иванович
# 0   2023-03-03 21:56:53                         Ельмикеев Евгений Иванович
# 468 2023-03-03 21:55:11                         Ельмикеев Евгений Иванович
# 34  2023-03-03 21:54:08  Научно-производственный центр информационных р...
# 902 2023-03-03 21:38:11                                      ИТ-Экспертиза
# 30  2023-03-03 21:20:45                                               МГТС
#
#                                                   name  \
# 384                          Экономист (себестоимость)
# 705                    Риск-аналитик (кредитные риски)
# 938                                      Риск-аналитик
# 571  Консультант отдела стратегии / бизнес-консультант
# 352           Junior / Junior+php программист (стажёр)
# 0                           Аналитик Power BI (стажер)
# 468                           Бизнес-аналитик (стажёр)
# 34   Fullstack программист-разработчик WEB-приложен...
# 902                    Руководитель инженерного отдела
# 30                Системный аналитик со знанием MS SQL
#
#                                            requirement  \
# 384  Опыт договорной работы (как преимущество). Опы...
# 705  Высшее техническое образование. Знание SQL и P...
# 938  Уверенное знание SQL, Python. Хорошие знания м...
# 571  Понимание принципов корреляционного, регрессио...
# 352  PHP 8+. Laravel 8. PostgreSQL/MySQL. - Знать к...
# 0    Кстати, Power Bi работает, все хорошо. -у тебя...
# 468  Главная задача должности бизнес-аналитика: най...
# 34   Знание JavaScript, SQL. Опыт работы c PоstgreS...
# 902  Отличное знание современных серверных технолог...
# 30   Знание языков программирования: Python, Sql, D...
#
#                                         responsibility  salary_from  \
# 384  Знание MS Excel (Продвинутый уровень), Power Q...          NaN
# 705  Построение и валидация скоринговых моделей. Оц...          NaN
# 938  Генерить и проверять гипотезы для усиления вну...          NaN
# 571  Подготовка презентаций, отчетов, а также марке...     100000.0
# 352  Основной стэк: - Работа с API. ⁃ Написанием мн...      25000.0
# 0    Вы точно прокачаетесь в задачах и решениях. А ...      25000.0
# 468  Ведение проектов по внедрению отчетности BI в ...      25000.0
# 34   Разработка программного обеспечения на веб-тех...      65000.0
# 902  Компания «ИТ-Экспертиза» — это команда професс...          NaN
# 30   1. Выгрузка из баз данных, анализ данных. 2. Н...          NaN
#
#      salary_to gross          schedule metro.station_name  \
# 384        NaN   NaN       Полный день                NaN
# 705        NaN   NaN       Полный день     Водный стадион
# 938        NaN   NaN       Полный день     Водный стадион
# 571        NaN     0       Полный день        Белорусская
# 352        NaN     0  Удаленная работа                NaN
# 0          NaN     0  Удаленная работа                NaN
# 468        NaN     0  Удаленная работа                NaN
# 34    140000.0     1       Полный день                NaN
# 902        NaN   NaN       Полный день                NaN
# 30         NaN   NaN       Полный день       Пролетарская
#
#                 metro.line_name                   alternate_url has_sql  \
# 384                         NaN  https://hh.ru/vacancy/77037203       0
# 705              Замоскворецкая  https://hh.ru/vacancy/72790924       1
# 938              Замоскворецкая  https://hh.ru/vacancy/72790429       1
# 571                   Кольцевая  https://hh.ru/vacancy/77181833       0
# 352                         NaN  https://hh.ru/vacancy/77097272       1
# 0                           NaN  https://hh.ru/vacancy/77097183       0
# 468                         NaN  https://hh.ru/vacancy/77097174       0
# 34                          NaN  https://hh.ru/vacancy/76612689       1
# 902                         NaN  https://hh.ru/vacancy/77181563       0
# 30   Таганско-Краснопресненская  https://hh.ru/vacancy/76536031       1
#
#     has_postgresql has_pandas has_powerbi has_excel
# 384              0          0           0         0
# 705              0          0           0         0
# 938              0          0           0         1
# 571              0          0           1         0
# 352              1          0           0         1
# 0                0          0           1         0
# 468              0          0           0         0
# 34               0          0           0         1
# 902              0          0           0         0
# 30               0          1           0         1

# %%
with pd.ExcelWriter(f'./hh_vacancy_parcer_{pd.Timestamp.today().strftime("%Y-%m-%d")}.xlsx', engine='xlsxwriter') as w:
    df.to_excel(w, sheet_name='data', index=False)

    w.sheets['data'].autofilter(0, 0, df.shape[0], df.shape[1]-1)
    w.sheets['data'].set_column(0, df.shape[1], 25)
